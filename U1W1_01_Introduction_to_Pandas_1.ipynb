# %% [markdown]
# # Advanced Certification in AIML
# ## A Program by IIIT-H and TalentSprint

# %% [markdown]
# ## Learning Objective

# %% [markdown]
# At the end of this experiment, you will be able to :
#
# * Use Pandas Library

# %% [markdown]
# ## Dataset

# %% [markdown]
# ### Description

# %% [markdown]
# The dataset choosen for this exercise is an employee dataset. The dataset contains the following information regarding a particular employee:
#
# * Emp ID
# * Name Prefix
# * First Name
# * Middle Initial
# * Last Name
# * Gender
# * E Mail
# * Father's Name
# * Mother's Name
# * Mother's Maiden Name
# * Date of Birth
# * Time of Birth
# * Age in Yrs
# *  Weight in Kgs
# * Date of Joining
# * Quarter of Joining
# * Half of Joining
# * Year of Joining
# * Month of Joining
# * Month Name of Joining
# * Short Month
# * Day of Joining
# * DOW of Joining
# * Short DOW
# * Age in Company (Years)
# * Salary
# * Last % Hike
# * SSN
# * Phone No
# * Place Name
# * CountyCity,
# * State
# * Zip
# * Region
# * User Name
# * Password

# %% [markdown]
# ## Setup Steps

# %%
#@title Please enter your registration id to start: { run: "auto", display-mode: "form" }
Id = "2100030" #@param {type:"string"}

# %%
#@title Please enter your password (normally your phone number) to continue: { run: "auto", display-mode: "form" }
password = "7674933144" #@param {type:"string"}

# %%
#@title Run this cell to complete the setup for this Notebook
from IPython import get_ipython

ipython = get_ipython()
  
notebook= "U1W1_01_Introduction_to_Pandas_1" #name of the notebook
Answer = "Ungraded"
def setup():
#  ipython.magic("sx pip3 install torch")
    ipython.magic("sx wget https://cdn.talentsprint.com/aiml/Experiment_related_data/Employee.csv")
    ipython.magic("sx wget https://cdn.talentsprint.com/aiml/Experiment_related_data/Large_employee.csv")
    from IPython.display import HTML, display
    display(HTML('<script src="https://dashboard.talentsprint.com/aiml/record_ip.html?traineeId={0}&recordId={1}"></script>'.format(getId(),submission_id)))
    print("Setup completed successfully")
    return

def submit_notebook():
    
    ipython.magic("notebook -e "+ notebook + ".ipynb")
    
    import requests, json, base64, datetime

    url = "https://dashboard.talentsprint.com/xp/app/save_notebook_attempts"
    if not submission_id:
      data = {"id" : getId(), "notebook" : notebook, "mobile" : getPassword()}
      r = requests.post(url, data = data)
      r = json.loads(r.text)

      if r["status"] == "Success":
          return r["record_id"]
      elif "err" in r:        
        print(r["err"])
        return None        
      else:
        print ("Something is wrong, the notebook will not be submitted for grading")
        return None

    elif getAnswer() and getComplexity() and getAdditional() and getConcepts():
      f = open(notebook + ".ipynb", "rb")
      file_hash = base64.b64encode(f.read())

      data = {"complexity" : Complexity, "additional" :Additional, 
              "concepts" : Concepts, "record_id" : submission_id, 
              "answer" : Answer, "id" : Id, "file_hash" : file_hash,
              "notebook" : notebook}

      r = requests.post(url, data = data)
      r = json.loads(r.text)
      print("Your submission is successful.")
      print("Ref Id:", submission_id)
      print("Date of submission: ", r["date"])
      print("Time of submission: ", r["time"])
      print("View your submissions: https://iiith-aiml.talentsprint.com/notebook_submissions")
     # print("For any queries/discrepancies, please connect with mentors through the chat icon in LMS dashboard.")
      return submission_id
    else: submission_id
    

def getAdditional():
  try:
    if not Additional: 
      raise NameError
    else:
      return Additional  
  except NameError:
    print ("Please answer Additional Question")
    return None

def getComplexity():
  try:
    if not Complexity:
      raise NameError
    else:
      return Complexity
  except NameError:
    print ("Please answer Complexity Question")
    return None
  
def getConcepts():
  try:
    if not Concepts:
      raise NameError
    else:
      return Concepts
  except NameError:
    print ("Please answer Concepts Question")
    return None

def getAnswer():
  try:
    if not Answer:
      raise NameError 
    else: 
      return Answer
  except NameError:
    print ("Please answer Question")
    return None

def getId():
  try: 
    return Id if Id else None
  except NameError:
    return None

def getPassword():
  try:
    return password if password else None
  except NameError:
    return None

submission_id = None
### Setup 
if getPassword() and getId():
  submission_id = submit_notebook()
  if submission_id:
    setup()
    
else:
  print ("Please complete Id and Password cells before running setup")
# Out:
# <script src="https://dashboard.talentsprint.com/aiml/record_ip.html?traineeId=2100030&recordId=353"></script>
# Setup completed successfully

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# ### a) Load the dataset

# %%
dataset = "Employee.csv"
# YOUR CODE HERE
import pandas as pd
data = pd.read_csv(dataset)

# %% [markdown]
# ### b) Display first 5 entries from the dataset

# %%
# YOUR CODE HERE
data.head(5)
# Out:
#    Emp ID Name Prefix First Name  ...     Region   User Name        Password
# 0  677509        Drs.       Lois  ...       West    lhwalker   DCa}.T}X:v?NP
# 1  940761         Ms.     Brenda  ...      South  bsrobinson   TCo\j#Zg;SQ~o
# 2  428945         Dr.        Joe  ...    Midwest  jwrobinson    GO4$J8MiEh[A
# 3  408351        Drs.      Diane  ...  Northeast     dievans   0gGRtp1HfL<r5
# 4  193819         Mr.   Benjamin  ...    Midwest   brrussell  Rd<Y8cp!@R;*%F
#
# [5 rows x 37 columns]

# %% [markdown]
# ### c) How many  records are there in the dataset?

# %%
# YOUR CODE HERE
data.count
# Out:
# <bound method DataFrame.count of     Emp ID Name Prefix First Name  ...     Region   User Name         Password
# 0   677509        Drs.       Lois  ...       West    lhwalker    DCa}.T}X:v?NP
# 1   940761         Ms.     Brenda  ...      South  bsrobinson    TCo\j#Zg;SQ~o
# 2   428945         Dr.        Joe  ...    Midwest  jwrobinson     GO4$J8MiEh[A
# 3   408351        Drs.      Diane  ...  Northeast     dievans    0gGRtp1HfL<r5
# 4   193819         Mr.   Benjamin  ...    Midwest   brrussell   Rd<Y8cp!@R;*%F
# ..     ...         ...        ...  ...        ...         ...              ...
# 95  639892         Mr.       Jose  ...      South      jkhill  a_!SKb6h3?w*Mad
# 96  704709         Dr.     Harold  ...    Midwest    hznelson      z/-hEz3&^q5
# 97  461593         Ms.     Nicole  ...    Midwest      noward   AUe6s0@:@]A3Ze
# 98  392491        Mrs.    Theresa  ...       West    trmurphy        V]PGw>4h9
# 99  495141        Drs.      Tammy  ...    Midwest     tbyoung  d6!&xu12A1H^i![
#
# [100 rows x 37 columns]>

# %% [markdown]
# ### d) How many columns are there in the dataset?

# %%
# YOUR CODE HERE
print(len((data.columns)))
# Out:
# 37

# %% [markdown]
# ### e) Print the name of all the columns

# %%
# YOUR CODE HERE
data.columns
# Out:
# Index(['Emp ID', 'Name Prefix', 'First Name', 'Middle Initial', 'Last Name',
#        'Gender', 'E Mail', 'Father's Name', 'Mother's Name',
#        'Mother's Maiden Name', 'Date of Birth', 'Time of Birth', 'Age in Yrs.',
#        'Weight in Kgs.', 'Date of Joining', 'Quarter of Joining',
#        'Half of Joining', 'Year of Joining', 'Month of Joining',
#        'Month Name of Joining', 'Short Month', 'Day of Joining',
#        'DOW of Joining', 'Short DOW', 'Age in Company (Years)', 'Salary',
#        'Last % Hike', 'SSN', 'Phone No. ', 'Place Name', 'County', 'City',
#        'State', 'Zip', 'Region', 'User Name', 'Password'],
#       dtype='object')

# %% [markdown]
# ### f) What is  the name of the 20th column ?

# %%
# YOUR CODE HERE
data.columns[19]
# Out:
# 'Month Name of Joining'

# %% [markdown]
# ### g) What is  the datatype of each column?

# %%
# YOUR CODE HERE
data.dtypes
# Out:
# Emp ID                      int64
# Name Prefix                object
# First Name                 object
# Middle Initial             object
# Last Name                  object
# Gender                     object
# E Mail                     object
# Father's Name              object
# Mother's Name              object
# Mother's Maiden Name       object
# Date of Birth              object
# Time of Birth              object
# Age in Yrs.               float64
# Weight in Kgs.              int64
# Date of Joining            object
# Quarter of Joining         object
# Half of Joining            object
# Year of Joining             int64
# Month of Joining            int64
# Month Name of Joining      object
# Short Month                object
# Day of Joining              int64
# DOW of Joining             object
# Short DOW                  object
# Age in Company (Years)    float64
# Salary                      int64
# Last % Hike                object
# SSN                        object
# Phone No.                  object
# Place Name                 object
# County                     object
# City                       object
# State                      object
# Zip                         int64
# Region                     object
# User Name                  object
# Password                   object
# dtype: object

# %% [markdown]
# ### h) Display the columns 4 to 9 for rows 7 to 13

# %%
# YOUR CODE HERE
data.loc[6:13,data.columns[3:9]]
# Out:
#    Middle Initial  Last Name  ...      Father's Name       Mother's Name
# 6               T      Baker  ...        Scott Baker          Judy Baker
# 7               V     Murphy  ...      Eugene Murphy    Katherine Murphy
# 8               B      Young  ...         Fred Young       Lillian Young
# 9               T   Peterson  ...  Jonathan Peterson  Christina Peterson
# 10              L     Flores  ...       Terry Flores     Michelle Flores
# 11              C  Alexander  ...   Samuel Alexander    Sharon Alexander
# 12              Q       King  ...        Philip King          Maria King
# 13              G     Watson  ...      Ronald Watson     Margaret Watson
#
# [8 rows x 6 columns]

# %% [markdown]
# ### i) Display all the rows after 50th row

# %%
# YOUR CODE HERE
data[51:]
# Out:
#     Emp ID Name Prefix   First Name  ...     Region     User Name         Password
# 51  447813        Mrs.          Ann  ...    Midwest     aqcoleman        g2]GlvlL5
# 52  525955        Drs.         Judy  ...  Northeast    jcgonzales   yDl}pfaWs{Hro6
# 53  818384         Mr.        Peter  ...    Midwest  pxwashington  97%d^2rk41!E>*Q
# 54  971640       Prof.     Clarence  ...      South        caross     h&jmac@+QD?B
# 55  253573         Ms.       Sharon  ...      South       selopez        GsP~S?FYY
# 56  904898        Drs.          Ann  ...       West      aqcooper       i_^#>]tFpt
# 57  515103         Ms.         Anne  ...      South       aaperez         y;n9A#}b
# 58  491943        Mrs.        Nancy  ...      South      nphoward        OC\&tG&?c
# 59  750173         Mr.      Antonio  ...      South     arroberts      h>.g!B:VcNN
# 60  687017         Ms.      Frances  ...       West      fpwatson   rjV1$at!wq53a$
# 61  241882         Ms.        Debra  ...    Midwest        dgwood  iO8B@*yA*mG6b9o
# 49             Williams     4/14/1996   03:43:43 AM        21.30
# 50                 Ward    10/31/1988   08:55:23 AM        28.76

# %% [markdown]
# ###  k) Display the information of the employees who have  joined in Quarter 1 and 4.

# %%
# YOUR CODE HERE
df = data[(data['Month of Joining'] <= 3) | (data['Month of Joining'] >= 10)]
df = data[data['Quarter of Joining'].isin(['Q1','Q4'])]
print(df)
# Out:
#     Emp ID Name Prefix   First Name  ...     Region     User Name         Password
# 0   677509        Drs.         Lois  ...       West      lhwalker    DCa}.T}X:v?NP
# 7   380086        Mrs.        Carol  ...    Midwest      cvmurphy     Uc+VG%vuZU<k
# 9   162402        Hon.        Diana  ...      South    dtpeterson   3o8>v&tYxjyEAo
# 11  153989       Prof.         Jack  ...       West   jcalexander   9L*-O1U.9mSUSh
# 12  386158        Mrs.      Melissa  ...    Midwest        mqking   FE5i<e-Y}[4f78
# 14  441771        Mrs.       Cheryl  ...  Northeast       coscott      Vbb+~2N|_yR
# 17  214352         Ms.      Theresa  ...    Midwest         tglee   JS#hN&Xij\%QEr
# 18  890290        Hon.        Julia  ...      South       jsscott       r.:Q7c^Tpb
# 21  969580       Prof.      Matthew  ...      South      mlturner  I>tL>d[|lZdi_|^
# 22  426038        Hon.         Joan  ...    Midwest     jcstewart   q@mq.U~D#1MPgZ
# 25  477253        Mrs.         Anne  ...    Midwest     alrussell     c8Nk&Y^~Vz!2
# 26  263480        Hon.       Daniel  ...    Midwest      dkcooper   d8p{Pwx2fsW0-Z
# 27  683826         Mr.        Roger  ...       West     rlroberts  41:C_0ik|Jb0iTO
# 28  474599        Drs.        Maria  ...      South      mwwalker        cw?%U}s{?
# 35  333476        Hon.         Mary  ...      South      mpwilson        Pwl&W:|<_
# 44  407061         Ms.    Elizabeth  ...  Northeast     eqjackson  EAHcnWsf6xMRwr]
# 46  702813         Mr.       Ernest  ...      South    edmartinez  qe?JNGBY{[\7;dD
# 47  524896         Ms.         Judy  ...    Midwest   jyhernandez  kiB:v!j&?D!&NYY
# 48  363065        Drs.        Nancy  ...  Northeast       nljones    J}HJq/zVF-Aq2
# 50  958326         Mr.        Larry  ...    Midwest      ltmiller     2WgF#:ew**x#
# 51  447813        Mrs.          Ann  ...    Midwest     aqcoleman        g2]GlvlL5
# 52  525955        Drs.         Judy  ...  Northeast    jcgonzales   yDl}pfaWs{Hro6
# 53  818384         Mr.        Peter  ...    Midwest  pxwashington  97%d^2rk41!E>*Q
# 54  971640       Prof.     Clarence  ...      South        caross     h&jmac@+QD?B
# 55  253573         Ms.       Sharon  ...      South       selopez        GsP~S?FYY
# 56  904898        Drs.          Ann  ...       West      aqcooper       i_^#>]tFpt
# 58  491943        Mrs.        Nancy  ...      South      nphoward        OC\&tG&?c
# 61  241882         Ms.        Debra  ...    Midwest        dgwood  iO8B@*yA*mG6b9o
# 63  940922        Hon.      Melissa  ...    Midwest      mxbutler       hY3BqUR>6F
# 65  917395        Hon.  Christopher  ...       West      cdnelson   QKae{1EP1A[SeX
# 68  293459         Mr.       Steven  ...      South    sjphillips      ht}X55$P&g1
# 69  732017         Ms.      Cynthia  ...       West     cjramirez   qP-#AhuNuz*Wb]
# 71  478003        Hon.      Cynthia  ...    Midwest       cxwhite   mofyGR>.?Dwb4!
# 77  870820         Ms.       Martha  ...      South  mgwashington      ju$7I]eH8{-
# 78  806955         Mr.      William  ...      South   wghernandez     BRB3DFywgZZ4
# 79  325319        Hon.      Carolyn  ...    Midwest       cfprice        K*$u@MAoH
# 82  761821         Mr.       Ernest  ...  Northeast  egwashington         B\Wb^6W-
# 83  400173         Ms.      Dorothy  ...  Northeast     dkedwards    VWEIm3YKm65|D
# 85  476433         Ms.      Lillian  ...    Midwest    lnmitchell         Ty/b@+;f
# 87  623929       Prof.        Jimmy  ...  Northeast      jrhoward   0v+|SfA0Xv+Pf%
# 89  212893         Ms.        Janet  ...      South   jyhenderson       g-oCs-L/za
# 90  185032         Mr.       Eugene  ...    Midwest       edperez       g]SJn<W_/#
# 91  867084         Ms.      Deborah  ...       West       desmith         C[WxHsB9
# 94  489424         Dr.      Phillip  ...       West       pfwhite   8<Mc.5]eu.*C8.
# 97  461593         Ms.       Nicole  ...    Midwest        noward   AUe6s0@:@]A3Ze
#
# [45 rows x 37 columns]

# %% [markdown]
# ### l) How many people are from the southern region joined on Monday?

# %%
# YOUR CODE HERE
dfsm = data.loc[(data['DOW of Joining'] == 'Monday') & (data['Region'] == 'South')]
print(len(dfsm))
# Out:
# 9

# %% [markdown]
# ### m) Display the information of the employees who have more than 13 years experience in the company

# %%
# YOUR CODE HERE
dfexp = data[data['Age in Company (Years)'] > 13]
print(dfexp)
# Out:
#     Emp ID Name Prefix   First Name  ...     Region    User Name         Password
# 0   677509        Drs.         Lois  ...       West     lhwalker    DCa}.T}X:v?NP
# 3   408351        Drs.        Diane  ...  Northeast      dievans    0gGRtp1HfL<r5
# 7   380086        Mrs.        Carol  ...    Midwest     cvmurphy     Uc+VG%vuZU<k
# 8   477616        Hon.      Frances  ...      South      fbyoung      K}^USc0l7[A
# 14  441771        Mrs.       Cheryl  ...  Northeast      coscott      Vbb+~2N|_yR
# 15  528509        Hon.        Paula  ...      South       pgdiaz         3Kg55luU
# 16  912990         Mr.       Joshua  ...    Midwest    jtstewart       K?vi9BBznj
# 19  622406         Mr.       Thomas  ...    Midwest      tqlewis   y;OJd_Oa#4g|!G
# 24  560455         Ms.      Carolyn  ...      South      cvhayes  NY!Y2sw.[_v-Q9{
# 28  474599        Drs.        Maria  ...      South     mwwalker        cw?%U}s{?
# 29  335732         Ms.       Brenda  ...       West     bmbutler     u+CtpZ~gyR*>
# 31  893212         Ms.          Amy  ...      South     abhoward         tNo::TEG
# 35  333476        Hon.         Mary  ...      South     mpwilson        Pwl&W:|<_
# 36  218791         Mr.        Aaron  ...    Midwest      anprice      uKxgV4uO&k@
# 40  923947         Ms.         Mary  ...    Midwest     mgbryant         A[iR?Z1{
# 52  525955        Drs.         Judy  ...  Northeast   jcgonzales   yDl}pfaWs{Hro6
# 57  515103         Ms.         Anne  ...      South      aaperez         y;n9A#}b
# 58  491943        Mrs.        Nancy  ...      South     nphoward        OC\&tG&?c
# 61  241882         Ms.        Debra  ...    Midwest       dgwood  iO8B@*yA*mG6b9o
# 65  917395        Hon.  Christopher  ...       West     cdnelson   QKae{1EP1A[SeX
# 70  915638         Dr.        Jason  ...    Midwest   jwanderson     a3Hlk+.V/TjD
# 71  478003        Hon.      Cynthia  ...    Midwest      cxwhite   mofyGR>.?Dwb4!
# 74  528673        Hon.         Paul  ...      South     pvwatson     7q{iHhbgWZ7%
# 78  806955         Mr.      William  ...      South  wghernandez     BRB3DFywgZZ4
# 85  476433         Ms.      Lillian  ...    Midwest   lnmitchell         Ty/b@+;f
# 91  867084         Ms.      Deborah  ...       West      desmith         C[WxHsB9
# 93  158666         Ms.      Rebecca  ...       West    rastewart   7ONuh3Zi^z#32r
# 97  461593         Ms.       Nicole  ...    Midwest       noward   AUe6s0@:@]A3Ze
#
# [28 rows x 37 columns]

# %% [markdown]
# ### n) There is a lot of redundant data. For example, the information in the below columns is also available in the *Date of Joining* column.
#
#   1.   month of Joining
#   2.   year of Joining
#   3.   Day of Joining
#
# There could be other such columns containing redundant data. Please identify such columns and take appropriate action.
#
#
# You can refer to the below link :
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html

# %%
# YOUR CODE HERE
data = data.drop(columns = ['Month of Joining', 'Year of Joining', 'Day of Joining'])
print(data.columns)
# Out:
# Index(['Emp ID', 'Name Prefix', 'First Name', 'Middle Initial', 'Last Name',
#        'Gender', 'E Mail', 'Father's Name', 'Mother's Name',
#        'Mother's Maiden Name', 'Date of Birth', 'Time of Birth', 'Age in Yrs.',
#        'Weight in Kgs.', 'Date of Joining', 'Quarter of Joining',
#        'Half of Joining', 'Month Name of Joining', 'Short Month',
#        'DOW of Joining', 'Short DOW', 'Age in Company (Years)', 'Salary',
#        'Last % Hike', 'SSN', 'Phone No. ', 'Place Name', 'County', 'City',
#        'State', 'Zip', 'Region', 'User Name', 'Password'],
#       dtype='object')

# %% [markdown]
# ### o) Remove "%" sign from the "Last % Hike" column values

# %% [markdown]
# you can refer the below link :
#
# https://stackoverflow.com/questions/52850192/python-extract-last-letter-of-a-string-from-a-pandas-column

# %%
# YOUR CODE HERE
data['Last % Hike'] = data['Last % Hike'].str.strip().str[:-1].astype(int)

print(data['Last % Hike'])
# Out:
# 0     21
# 1     27
# 2     16
# 3      1
# 4     13
#       ..
# 95    15
# 96     0
# 97    12
# 98    11
# 99     7
# Name: Last % Hike, Length: 100, dtype: int64

# %% [markdown]
# ### p) How many Female employees got hike more than 20% ?

# %%
# YOUR CODE HERE
dffm = data[(data['Gender'] == 'F') & (data['Last % Hike'] > 20)]
print(dffm['Last % Hike'])
# Out:
# 0     21
# 1     27
# 8     28
# 20    30
# 25    29
# 28    21
# 29    29
# 30    22
# 31    30
# 41    22
# 44    24
# 47    30
# 55    21
# 56    30
# 58    25
# 60    22
# 63    30
# 66    25
# 71    30
# 77    25
# 88    22
# 91    28
# 92    25
# Name: Last % Hike, dtype: int64

# %% [markdown]
# ### Summary

# %% [markdown]
# To know more about Pandas, you can refer below link :
#
# https://www.machinelearningplus.com/python/101-pandas-exercises-python/
